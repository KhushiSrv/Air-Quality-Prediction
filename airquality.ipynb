# %%
import numpy as np
import pandas as pd
import os

# %%
data1 = pd.read_csv("city_day.csv")
# Out:
# C:\Users\khush\AppData\Local\Temp\ipykernel_24824\1414943133.py:4: DtypeWarning:
#
# Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
data1.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
data1 = data1.dropna()

# %%
data1
# Out:
#                 City        Date  PM2.5    PM10    NO    NO2    NOx    NH3  \
# 2123       Amaravati  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72
# 2124       Amaravati  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28
# 2125       Amaravati  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91
# 2126       Amaravati  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42
# 2127       Amaravati  2017-11-29  72.47  114.84  5.23  23.20  16.59  12.25
# ...              ...         ...    ...     ...   ...    ...    ...    ...
# 29525  Visakhapatnam  2020-06-26   7.63   32.27  5.91  23.27  17.19  11.15
# 29526  Visakhapatnam  2020-06-27  15.02   50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38   74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91   65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64   49.97  4.05  29.26  18.80  10.03
#
# ...

# %%
data1['City'].unique()
# Out:
# array(['Amaravati', 'Amritsar', 'Chandigarh', 'Delhi', 'Gurugram',
#        'Hyderabad', 'Kolkata', 'Patna', 'Visakhapatnam'], dtype=object)

# %%
data_delhi = data1[(data1['City'] == "Delhi")]

# %%
import plotly.express as px

# %%
fig = px.line(data_delhi, x="Date", y="PM2.5")
fig.show()

# %%
import plotly.graph_objects as go

# %%
Mar_may_2019=data_delhi[(data_delhi['Date'] >= '2019-03') & (data_delhi['Date'] <= '2019-05') ]
Mar_may_2020=data_delhi[(data_delhi['Date'] >= '2020-03') & (data_delhi['Date'] <= '2020-05') ]

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=Mar_may_2019['Date'], y=Mar_may_2019['PM2.5'],
                    mode='lines+markers',
                    name='PM2.5 levels of 2019'))
fig.add_trace(go.Scatter(x=Mar_may_2019['Date'], y=Mar_may_2020['PM2.5'],
                    mode='lines+markers',
                    name='PM2.5 levels of 2020'))
#fig.title("PM2.5 Value valiations in Delhi in year 2019 and 2020")

fig.show()

# %%
data1
# Out:
#                 City        Date  PM2.5    PM10    NO    NO2    NOx    NH3  \
# 2123       Amaravati  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72
# 2124       Amaravati  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28
# 2125       Amaravati  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91
# 2126       Amaravati  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42
# 2127       Amaravati  2017-11-29  72.47  114.84  5.23  23.20  16.59  12.25
# ...              ...         ...    ...     ...   ...    ...    ...    ...
# 29525  Visakhapatnam  2020-06-26   7.63   32.27  5.91  23.27  17.19  11.15
# 29526  Visakhapatnam  2020-06-27  15.02   50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38   74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91   65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64   49.97  4.05  29.26  18.80  10.03
#
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6236 entries, 2123 to 29529
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        6236 non-null   object
#  1   Date        6236 non-null   object
#  2   PM2.5       6236 non-null   float64
#  3   PM10        6236 non-null   float64
#  4   NO          6236 non-null   float64
#  5   NO2         6236 non-null   float64
#  6   NOx         6236 non-null   float64
#  7   NH3         6236 non-null   float64
#  8   CO          6236 non-null   float64
#  9   SO2         6236 non-null   float64
#  10  O3          6236 non-null   float64
#  11  Benzene     6236 non-null   float64
#  12  Toluene     6236 non-null   float64
#  13  Xylene      6236 non-null   float64
#  14  AQI         6236 non-null   float64
#  15  AQI_Bucket  6236 non-null   object
# dtypes: float64(13), object(3)
# memory usage: 828.2+ KB

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
data1['AQI_Bucket'] = label_encoder.fit_transform(data1['AQI_Bucket'])
data1['City'] = label_encoder.fit_transform(data1['City'])
data1['Date'] = label_encoder.fit_transform(data1['Date'])

# %%
#data_attributes = data1.select_dtypes(include = np.float64)

# %%
data1
# Out:
#        City  Date  PM2.5    PM10    NO    NO2    NOx    NH3    CO    SO2  \
# 2123      0   878  81.40  124.50  1.44  20.50  12.08  10.72  0.12  15.24
# 2124      0   879  78.32  129.06  1.26  26.00  14.85  10.28  0.14  26.96
# 2125      0   880  88.76  135.32  6.60  30.85  21.77  12.91  0.11  33.59
# 2126      0   881  64.18  104.09  2.56  28.07  17.01  11.42  0.09  19.00
# 2127      0   882  72.47  114.84  5.23  23.20  16.59  12.25  0.16  10.55
# ...     ...   ...    ...     ...   ...    ...    ...    ...   ...    ...
# 29525     8  1822   7.63   32.27  5.91  23.27  17.19  11.15  0.46   6.87
# 29526     8  1823  15.02   50.94  7.68  25.06  19.54  12.47  0.47   8.55
# 29527     8  1824  24.38   74.09  3.42  26.06  16.53  11.99  0.52  12.72
# 29528     8  1825  22.91   65.73  3.45  29.53  18.33  10.71  0.48   8.42
# 29529     8  1826  16.64   49.97  4.05  29.26  18.80  10.03  0.52   9.84
#
#            O3  Benzene  Toluene  Xylene    AQI  AQI_Bucket
# ...

# %%
data1.corr()['AQI'].sort_values(ascending = False)
# Out:
# AQI           1.000000
# PM2.5         0.924028
# PM10          0.916576
# NOx           0.658264
# NO            0.622031
# NH3           0.589695
# NO2           0.576308
# CO            0.494508
# Toluene       0.466346
# AQI_Bucket    0.396287
# O3            0.334609
# SO2           0.254686
# Benzene       0.207927
# Xylene        0.073873
# City         -0.105177
# Date         -0.260240
# Name: AQI, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
f,ax = plt.subplots(figsize = (18,18))
cmap = sns.diverging_palette(220,10,as_cmap = True)
heatmap = sns.heatmap(data1.corr(), cmap = cmap, vmax = 1, linewidths = 1, ax =  ax)
plt.show()

# %%
cols = data1.corr()['AQI'][(data1.corr()['AQI'])<=0.4].index
cols
# Out:
# Index(['City', 'Date', 'SO2', 'O3', 'Benzene', 'Xylene', 'AQI_Bucket'], dtype='object')

# %%
data1= data1.drop(columns = cols, axis = 1)

# %%
data1
# Out:
#        PM2.5    PM10    NO    NO2    NOx    NH3    CO  Toluene    AQI
# 2123   81.40  124.50  1.44  20.50  12.08  10.72  0.12     6.50  184.0
# 2124   78.32  129.06  1.26  26.00  14.85  10.28  0.14     7.95  197.0
# 2125   88.76  135.32  6.60  30.85  21.77  12.91  0.11     7.63  198.0
# 2126   64.18  104.09  2.56  28.07  17.01  11.42  0.09     5.02  188.0
# 2127   72.47  114.84  5.23  23.20  16.59  12.25  0.16     4.71  173.0
# ...      ...     ...   ...    ...    ...    ...   ...      ...    ...
# 29525   7.63   32.27  5.91  23.27  17.19  11.15  0.46     5.37   47.0
# 29526  15.02   50.94  7.68  25.06  19.54  12.47  0.47    12.07   41.0
# 29527  24.38   74.09  3.42  26.06  16.53  11.99  0.52     2.21   70.0
# 29528  22.91   65.73  3.45  29.53  18.33  10.71  0.48     0.01   68.0
# 29529  16.64   49.97  4.05  29.26  18.80  10.03  0.52     0.00   54.0
#
# [6236 rows x 9 columns]

# %%
moderate = data1.AQI[data1.AQI_Bucket == 'Moderate']
poor     = data1.AQI[data1.AQI_Bucket == 'Poor']
very_poor= data1.AQI[data1.AQI_Bucket == 'Very Poor']
satisfactory     = data1.AQI[data1.AQI_Bucket == 'Satisfactory']
good = data1.AQI[data1.AQI_Bucket == 'Good']
severe     = data1.AQI[data1.AQI_Bucket == 'Severe']

# %%
data1.columns
# Out:
# Index(['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'Toluene', 'AQI'], dtype='object')

# %%
X = data1.drop(columns = ['AQI']).values
Y = data1['AQI']

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6236 entries, 2123 to 29529
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PM2.5    6236 non-null   float64
#  1   PM10     6236 non-null   float64
#  2   NO       6236 non-null   float64
#  3   NO2      6236 non-null   float64
#  4   NOx      6236 non-null   float64
#  5   NH3      6236 non-null   float64
#  6   CO       6236 non-null   float64
#  7   Toluene  6236 non-null   float64
#  8   AQI      6236 non-null   float64
# dtypes: float64(9)
# memory usage: 487.2 KB

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(data1)
X
# Out:
# array([[ 0.37375467,  0.01260924, -0.7773514 , ..., -0.63739749,
#         -0.31121784,  0.46898787],
#        [ 0.31640473,  0.06576563, -0.78633513, ..., -0.62264879,
#         -0.19319961,  0.60917773],
#        [ 0.51079868,  0.13873909, -0.51981791, ..., -0.64477184,
#         -0.21924501,  0.61996156],
#        ...,
#        [-0.68796401, -0.57502528, -0.67853041, ..., -0.34242355,
#         -0.66038901, -0.76036931],
#        [-0.71533557, -0.67247866, -0.67703313, ..., -0.37192094,
#         -0.83945115, -0.78193697],
#        [-0.83208366, -0.85619459, -0.64708737, ..., -0.34242355,
#         -0.84026507, -0.93291066]])

# %%
from sklearn.model_selection import train_test_split
X_Train, X_Test, Y_Train, Y_Test = train_test_split(X,Y, test_size = 0.2, random_state = 0)

# %%
print(X_Train.shape)
print(X_Test.shape)
print(Y_Train.shape)
print(Y_Test.shape)
# Out:
# (4988, 9)
# (1248, 9)
# (4988,)
# (1248,)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_Train, Y_Train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
Y_Pred = model.predict(X_Test)
mse = mean_squared_error(Y_Test, Y_Pred)
mae = mean_absolute_error(Y_Test, Y_Pred)
r2 = r2_score(Y_Test, Y_Pred)
print("Mean Squared Error : ", mse)
print("Mean Absolute Error : ", mae)
print("R2-Score : ", r2)
# Out:
# Mean Squared Error :  9.954049174105707e-27
# Mean Absolute Error :  6.807090503804293e-14
# R2-Score :  1.0

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.scatter(Y_Test, Y_Pred, color='blue', alpha=0.5)
plt.plot(Y_Test, Y_Pred, color='red', linestyle='--')
plt.title('Model Predictions vs. Actual Measurements')
plt.xlabel('Actual Measurements')
plt.ylabel('Predicted Values')
plt.grid(True)
plt.show()
